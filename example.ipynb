# %%
from mxscreen.burn import burner
import matplotlib.pyplot as plt

f1 = "/Users/dkreitler/xray/mxscreen_test_data/proteinaseK_static_burn_center_24539_master.h5"
f2 = "/Users/dkreitler/xray/mxscreen_test_data/SPOT_BURN_PK_DIALS.XDS"
f3 = "/Users/dkreitler/xray/mxscreen_test_data/SPOT_BURN_PK_DOZOR.XDS"
    
burnExperimentDials = burner.BurnExperiment(f2,
                                            f1,
                                            nResShells=10,
                                            resRangeAll=(1,5),
                                            nPsiWedges=1,
                                            psiRangeAll=(0,180),
                                            frameRangeAll=(2,175),
                                            decayStrategy="doubleExponential")

burnExperimentDials.psiBounds()
dialsBounds=burnExperimentDials.resBounds()
print('dialsBounds',dialsBounds)
boundsdict={'resBounds': dialsBounds}
burnExperimentDozor = burner.BurnExperiment(f3,
                                            f1,
                                            nResShells=10,
                                            resRangeAll=(1,5),
                                            nPsiWedges=1,
                                            psiRangeAll=(270,360),
                                            frameRangeAll=(2,175),
                                            decayStrategy="doubleExponential",
                                            **boundsdict)
burnExperimentDozor.psiBounds()
#burnExperimentDozor.resBounds()
burnExperimentDials.rangesDictList()
burnExperimentDozor.rangesDictList()
burnExperimentDials.spotGroupList()
burnExperimentDozor.spotGroupList()
burnExperimentDials.fitSpotGroups()
burnExperimentDozor.fitSpotGroups()
resultsDials = burnExperimentDials.experimentPlot()
resultsDozor = burnExperimentDozor.experimentPlot()
    
print('dials results\n',resultsDials)
print('dozor results\n',resultsDozor)
    
plt.plot(resultsDials[:,0],resultsDials[:,1],'b-o',label='dials')
plt.plot(resultsDozor[:,0],resultsDozor[:,1],'g-o',label='dozor')
plt.legend()
plt.ylabel('Half life as Frame no.')
plt.xlabel('resolution bin number')
plt.show()
# Out:
# 254518
# DIMSIZE 25451
# RESBOUNDS  [1.11504301 1.97165096 2.22320969 2.46486892 2.69921323 2.92650869
#  3.20759107 3.48046812 3.85988894 4.27777565 4.99837116]
# dialsBounds [1.11504301 1.97165096 2.22320969 2.46486892 2.69921323 2.92650869
#  3.20759107 3.48046812 3.85988894 4.27777565 4.99837116]
# resRangeBounds  [1.11504301 1.97165096 2.22320969 2.46486892 2.69921323 2.92650869
#  3.20759107 3.48046812 3.85988894 4.27777565 4.99837116]
# resRangeBounds  [1.11504301 1.97165096 2.22320969 2.46486892 2.69921323 2.92650869
#  3.20759107 3.48046812 3.85988894 4.27777565 4.99837116]
# RANGESTEST {'resBin': 0, 'psiWedge': 0, 'resRange': (1.1150430064108419, 1.9716509636401365), 'psiRange': (0.0, 180.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 1, 'psiWedge': 0, 'resRange': (1.9716509636401365, 2.223209693296344), 'psiRange': (0.0, 180.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 2, 'psiWedge': 0, 'resRange': (2.223209693296344, 2.464868920244304), 'psiRange': (0.0, 180.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 3, 'psiWedge': 0, 'resRange': (2.464868920244304, 2.6992132290927113), 'psiRange': (0.0, 180.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 4, 'psiWedge': 0, 'resRange': (2.6992132290927113, 2.92650869179967), 'psiRange': (0.0, 180.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 5, 'psiWedge': 0, 'resRange': (2.92650869179967, 3.207591066955849), 'psiRange': (0.0, 180.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 6, 'psiWedge': 0, 'resRange': (3.207591066955849, 3.480468119101039), 'psiRange': (0.0, 180.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 7, 'psiWedge': 0, 'resRange': (3.480468119101039, 3.8598889391486835), 'psiRange': (0.0, 180.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 8, 'psiWedge': 0, 'resRange': (3.8598889391486835, 4.277775654638669), 'psiRange': (0.0, 180.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 9, 'psiWedge': 0, 'resRange': (4.277775654638669, 4.998371155328446), 'psiRange': (0.0, 180.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 0, 'psiWedge': 0, 'resRange': (1.1150430064108419, 1.9716509636401365), 'psiRange': (270.0, 360.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 1, 'psiWedge': 0, 'resRange': (1.9716509636401365, 2.223209693296344), 'psiRange': (270.0, 360.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 2, 'psiWedge': 0, 'resRange': (2.223209693296344, 2.464868920244304), 'psiRange': (270.0, 360.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 3, 'psiWedge': 0, 'resRange': (2.464868920244304, 2.6992132290927113), 'psiRange': (270.0, 360.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 4, 'psiWedge': 0, 'resRange': (2.6992132290927113, 2.92650869179967), 'psiRange': (270.0, 360.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 5, 'psiWedge': 0, 'resRange': (2.92650869179967, 3.207591066955849), 'psiRange': (270.0, 360.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 6, 'psiWedge': 0, 'resRange': (3.207591066955849, 3.480468119101039), 'psiRange': (270.0, 360.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 7, 'psiWedge': 0, 'resRange': (3.480468119101039, 3.8598889391486835), 'psiRange': (270.0, 360.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 8, 'psiWedge': 0, 'resRange': (3.8598889391486835, 4.277775654638669), 'psiRange': (270.0, 360.0), 'frameRange': (2, 175)}
# RANGESTEST {'resBin': 9, 'psiWedge': 0, 'resRange': (4.277775654638669, 4.998371155328446), 'psiRange': (270.0, 360.0), 'frameRange': (2, 175)}
# dials results
#  [[ 0.          7.8167333   1.11504301  1.97165096]
#  [ 1.         14.25704132  1.97165096  2.22320969]
#  [ 2.         15.16699043  2.22320969  2.46486892]
#  [ 3.         18.19640651  2.46486892  2.69921323]
#  [ 4.         20.37943617  2.69921323  2.92650869]
#  [ 5.         21.0374961   2.92650869  3.20759107]
#  [ 6.         23.05334283  3.20759107  3.48046812]
#  [ 7.         32.09248142  3.48046812  3.85988894]
#  [ 8.         32.32849423  3.85988894  4.27777565]
#  [ 9.         50.64487695  4.27777565  4.99837116]]
# dozor results
#  [[ 0.          8.16986684  1.11504301  1.97165096]
#  [ 1.         12.60389975  1.97165096  2.22320969]
#  [ 2.         14.30214289  2.22320969  2.46486892]
#  [ 3.         14.25391965  2.46486892  2.69921323]
#  [ 4.         17.91804806  2.69921323  2.92650869]
#  [ 5.         24.45712346  2.92650869  3.20759107]
#  [ 6.         25.86083185  3.20759107  3.48046812]
#  [ 7.         26.73022393  3.48046812  3.85988894]
#  [ 8.         34.00982367  3.85988894  4.27777565]
#  [ 9.         42.71269536  4.27777565  4.99837116]]
